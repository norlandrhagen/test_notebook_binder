# %% [markdown]
# # Plot Regional Maps (Satellite, Model)
#
# Create a regional map using satellite and model data.
# <br/> <br/>
# **Notes:**<br/>
# * Pisces model is a weekly-averaged global model with spatial resolution $\frac{1}{2}^\circ \times \frac{1}{2}^\circ$ (data is available only at one-week intervals).<br/>
#
# * Satellite SST data set is a daily-global product with spatial resolution $\frac{1}{4}^\circ \times \frac{1}{4}^\circ$.<br/>

# %%
import opedia
opedia.API('9c5d8ab0-819f-11e9-b586-7313dd010cc8')
from opedia import plotRegional as REG

tables = ['tblSeaFlow']    # see catalog.csv  for the complete list of tables and variable names
variables = ['total_biomass']                                         # see catalog.csv  for the complete list of tables and variable names
startDate = '2017-08-03'
endDate = '2017-09-01'
lat1, lat2 = 28, 90
lon1, lon2 = -180, 180
depth1, depth2 = 0, 5
fname = 'ts'
exportDataFlag = False       # True if you you want to download data       

REG.regionalMap(tables, variables, startDate, endDate, lat1, lat2, lon1, lon2, depth1, depth2, fname, exportDataFlag)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# HBox(children=(IntProgress(value=0, description='overall', max=1, style=ProgressStyle(description_width='initi…
# 1: total_biomass retrieved (tblSeaFlow).
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1197">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="96cc4521-d503-49dc-b8b7-9fb5fc9950b3" data-root-id="1198"></div>
